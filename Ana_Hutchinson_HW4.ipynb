# %% [markdown]
# # HW Assignment 4

# %% [markdown]
# ## Problem 1

# %%
# Write a program using function that asks the user to enter a distance in kilometers, then converts that distance to miles. 
# The conversion formula is as follows: Miles = Kilometers x 0.6214

def miles(kilometers):
    return kilometers * 0.6214

if __name__ == "__main__":
    kilometers = float(input("Enter distance in kilometers: "))
    
    miles = miles(kilometers)
    print(f"{kilometers} kilometers is equal to {miles:.2f} miles.")
# Out:
# 6.0 kilometers is equal to 3.73 miles.

# %% [markdown]
# ## Problem 2

# %%
# Many financial experts advise that property owners should insure their homes or 
# buildings for at least 80 percent of the amount it would cost to replace the structure. 
# Write a program using function that asks the user to enter the replacement cost of a building, 
# then displays the minimum amount of insurance he or she should buy for the property.

def insurance(replacement_cost):
    return replacement_cost * 0.80

if __name__ == "__main__":
    replacement_cost = float(input("Enter the replacement cost of the building: "))
    
    insurance_amount = insurance(replacement_cost)
    print(f"The minimum amount of insurance you should buy is ${insurance_amount:.2f}.")
# Out:
# The minimum amount of insurance you should buy is $80.00.

# %% [markdown]
# ## Problem 3

# %%
# Write a program that asks the user to enter the monthly costs for the following expenses incurred 
# from operating his or her automobile: loan payment, insurance, gas, oil, tires, and maintenance. 
# The program should then display the total monthly cost of these expenses, and the total annual cost of these expenses.

def monthly_cost(loan_payment, insurance, gas, oil, tires, maintenance):
    return loan_payment + insurance + gas + oil + tires + maintenance

if __name__ == "__main__":
    loan_payment = float(input("Enter the monthly loan payment: "))
    insurance = float(input("Enter the monthly insurance cost: "))
    gas = float(input("Enter the monthly gas cost: "))
    oil = float(input("Enter the monthly oil cost: "))
    tires = float(input("Enter the monthly tires cost: "))
    maintenance = float(input("Enter the monthly maintenance cost: "))

    total_monthly_cost = monthly_cost(loan_payment, insurance, gas, oil, tires, maintenance)
    total_annual_cost = total_monthly_cost * 12

    print(f"The total monthly cost is ${total_monthly_cost:.2f}.")
    print(f"The total annual cost is ${total_annual_cost:.2f}.")
# Out:
# The total monthly cost is $600.00.
# The total annual cost is $7200.00.

# %% [markdown]
# ## Problem 4

# %%
# There are three seating categories at a stadium. Class A seats cost $20, Class B seats cost $15, 
# and Class C seats cost $10. Write a program using function that asks how many tickets for each class 
# of seats were sold, then displays the amount of income generated from ticket sales.

def income(class_a_tickets, class_b_tickets, class_c_tickets):
    return (class_a_tickets * 20) + (class_b_tickets * 15) + (class_c_tickets * 10)

if __name__ == "__main__":
    class_a_tickets = int(input("Enter the number of Class A tickets sold: "))
    class_b_tickets = int(input("Enter the number of Class B tickets sold: "))
    class_c_tickets = int(input("Enter the number of Class C tickets sold: "))

    total_income = income(class_a_tickets, class_b_tickets, class_c_tickets)
    print(f"The total income generated from ticket sales is ${total_income:.2f}.")
# Out:
# The total income generated from ticket sales is $450.00.

# %% [markdown]
# ## Problem 5

# %%
# One foot equals 12 inches. Write a function named feet to inches that accepts a number of feet as an argument 
# and returns the number of inches in that many feet. Use the function in a program that prompts the user to 
# enter a number of feet then displays the number of inches in that many feet.

def feet_to_inches(feet):
    return feet * 12

if __name__ == "__main__":
    feet = float(input("Enter the number of feet: "))
    
    inches = feet_to_inches(feet)
    print(f"{feet} feet is equal to {inches:.2f} inches.")
# Out:
# 2.0 feet is equal to 24.00 inches.

# %% [markdown]
# ## Problem 6

# %%
# Write a function named max that accepts two integer values as arguments and returns the value that is 
# the greater of the two. For example, if 7 and 12 are passed as arguments to the function, the function 
# should return 12. Use the function in a program that prompts the user to enter two integer values. The
# program should display the value that is the greater of the two.

def max(a, b):
    if a > b:
        return a
    else:
        return b
    
if __name__ == "__main__":
    num1 = int(input("Enter the first integer: "))
    num2 = int(input("Enter the second integer: "))
    
    greater_value = max(num1, num2)
    print(f"The greater value is {greater_value}.")
# Out:
# The greater value is 10.
